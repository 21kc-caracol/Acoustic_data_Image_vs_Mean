# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.0.0

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
series = trend(time, 0.1)  
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Update with noise
series += noise(time, noise_level, seed=42)

split_time = 1000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

tf.keras.backend.clear_session()
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
print(model.summary())
history = model.fit(dataset, epochs=100, callbacks=[lr_schedule])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, None, 1)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 64)          8704
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                24832
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 1)                 0
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 31/31 [==============================] - 7s 236ms/step - loss: 21.4949 - mae: 22.0115
# Epoch 2/100
# 31/31 [==============================] - 1s 25ms/step - loss: 21.2168 - mae: 21.6440
# Epoch 3/100
# 31/31 [==============================] - 1s 25ms/step - loss: 20.7111 - mae: 21.2278
# Epoch 4/100
# 31/31 [==============================] - 1s 26ms/step - loss: 20.1562 - mae: 20.7739: 0s - loss: 20.1519 - mae: 20.642
# Epoch 5/100
# 31/31 [==============================] - 1s 25ms/step - loss: 19.7903 - mae: 20.2843
# Epoch 6/100
# 31/31 [==============================] - 1s 25ms/step - loss: 19.2615 - mae: 19.6776
# Epoch 7/100
# 31/31 [==============================] - 1s 25ms/step - loss: 18.2681 - mae: 18.7308
# Epoch 8/100
# 31/31 [==============================] - 1s 25ms/step - loss: 17.4057 - mae: 17.9757
# Epoch 9/100
# 31/31 [==============================] - 1s 25ms/step - loss: 17.2263 - mae: 17.6581
# Epoch 10/100
# 31/31 [==============================] - 1s 25ms/step - loss: 16.8978 - mae: 17.3457
# Epoch 11/100
# 31/31 [==============================] - 1s 26ms/step - loss: 16.6165 - mae: 17.0459
# Epoch 12/100
# 31/31 [==============================] - 1s 25ms/step - loss: 16.2132 - mae: 16.7529
# Epoch 13/100
# 31/31 [==============================] - 1s 25ms/step - loss: 15.9664 - mae: 16.4573
# Epoch 14/100
# 31/31 [==============================] - 1s 24ms/step - loss: 15.6962 - mae: 16.1587
# Epoch 15/100
# 31/31 [==============================] - 1s 25ms/step - loss: 15.3739 - mae: 15.8571
# Epoch 16/100
# 31/31 [==============================] - 1s 25ms/step - loss: 15.1133 - mae: 15.5765
# Epoch 17/100
# 31/31 [==============================] - 1s 24ms/step - loss: 14.7837 - mae: 15.2950
# Epoch 18/100
# 31/31 [==============================] - 1s 25ms/step - loss: 14.4760 - mae: 15.0164: 0s - loss: 14.3420 - mae:
# Epoch 19/100
# 31/31 [==============================] - 1s 25ms/step - loss: 14.3366 - mae: 14.7612
# Epoch 20/100
# 31/31 [==============================] - 1s 25ms/step - loss: 14.0852 - mae: 14.5354
# Epoch 21/100
# 31/31 [==============================] - 1s 27ms/step - loss: 13.8134 - mae: 14.3081
# Epoch 22/100
# 31/31 [==============================] - 1s 26ms/step - loss: 13.6393 - mae: 14.1062
# Epoch 23/100
# 31/31 [==============================] - 1s 27ms/step - loss: 13.3826 - mae: 13.8858
# Epoch 24/100
# 31/31 [==============================] - 1s 26ms/step - loss: 13.1954 - mae: 13.7037
# Epoch 25/100
# 31/31 [==============================] - 1s 24ms/step - loss: 13.0163 - mae: 13.4526
# Epoch 26/100
# 31/31 [==============================] - 1s 25ms/step - loss: 12.7585 - mae: 13.2327
# Epoch 27/100
# 31/31 [==============================] - 1s 25ms/step - loss: 12.5284 - mae: 12.9716
# Epoch 28/100
# 31/31 [==============================] - 1s 26ms/step - loss: 12.2087 - mae: 12.7095
# Epoch 29/100
# 31/31 [==============================] - 1s 26ms/step - loss: 12.3941 - mae: 12.8460
# Epoch 30/100
# 31/31 [==============================] - 1s 26ms/step - loss: 11.8443 - mae: 12.3121
# Epoch 31/100
# 31/31 [==============================] - 1s 27ms/step - loss: 11.3303 - mae: 11.8148
# Epoch 32/100
# 31/31 [==============================] - 1s 29ms/step - loss: 10.9481 - mae: 11.4830
# Epoch 33/100
# 31/31 [==============================] - 1s 27ms/step - loss: 10.6266 - mae: 11.1361
# Epoch 34/100
# 31/31 [==============================] - 1s 29ms/step - loss: 10.7815 - mae: 11.3007
# Epoch 35/100
# 31/31 [==============================] - 1s 29ms/step - loss: 10.9719 - mae: 11.4607
# Epoch 36/100
# 31/31 [==============================] - 1s 26ms/step - loss: 10.4490 - mae: 10.9636
# Epoch 37/100
# 31/31 [==============================] - 1s 26ms/step - loss: 9.9899 - mae: 10.4892
# Epoch 38/100
# 31/31 [==============================] - 1s 25ms/step - loss: 9.5782 - mae: 10.0283
# Epoch 39/100
# 31/31 [==============================] - 1s 25ms/step - loss: 9.0664 - mae: 9.5461
# Epoch 40/100
# 31/31 [==============================] - 1s 26ms/step - loss: 8.6547 - mae: 9.1358
# Epoch 41/100
# 31/31 [==============================] - 1s 26ms/step - loss: 8.2887 - mae: 8.7356
# Epoch 42/100
# 31/31 [==============================] - 1s 29ms/step - loss: 7.9123 - mae: 8.4081
# Epoch 43/100
# 31/31 [==============================] - 1s 27ms/step - loss: 7.6793 - mae: 8.1137
# Epoch 44/100
# 31/31 [==============================] - 1s 27ms/step - loss: 7.3547 - mae: 7.8033
# Epoch 45/100
# 31/31 [==============================] - 1s 26ms/step - loss: 7.1047 - mae: 7.5770
# Epoch 46/100
# 31/31 [==============================] - 1s 25ms/step - loss: 6.9459 - mae: 7.3933
# Epoch 47/100
# 31/31 [==============================] - 1s 25ms/step - loss: 6.5524 - mae: 7.0771
# Epoch 48/100
# 31/31 [==============================] - 1s 28ms/step - loss: 6.4136 - mae: 6.9074
# Epoch 49/100
# 31/31 [==============================] - 1s 27ms/step - loss: 6.3931 - mae: 6.8757
# Epoch 50/100
# 31/31 [==============================] - 1s 25ms/step - loss: 6.0520 - mae: 6.5164
# Epoch 51/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.8715 - mae: 6.3634
# Epoch 52/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.7791 - mae: 6.2421
# Epoch 53/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.6699 - mae: 6.1419
# Epoch 54/100
# 31/31 [==============================] - 1s 25ms/step - loss: 5.5072 - mae: 5.9468
# Epoch 55/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.4385 - mae: 5.9006
# Epoch 56/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.2939 - mae: 5.7471
# Epoch 57/100
# 31/31 [==============================] - 1s 30ms/step - loss: 5.3199 - mae: 5.7881
# Epoch 58/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.1544 - mae: 5.6591
# Epoch 59/100
# 31/31 [==============================] - 1s 29ms/step - loss: 5.3091 - mae: 5.7545
# Epoch 60/100
# 31/31 [==============================] - 1s 29ms/step - loss: 5.0288 - mae: 5.5567
# Epoch 61/100
# 31/31 [==============================] - 1s 28ms/step - loss: 4.9551 - mae: 5.4250
# Epoch 62/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.1300 - mae: 5.5808
# Epoch 63/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.2117 - mae: 5.6629
# Epoch 64/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.0574 - mae: 5.5312
# Epoch 65/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.9261 - mae: 5.3900
# Epoch 66/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.3048 - mae: 5.7638
# Epoch 67/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.2755 - mae: 5.7445
# Epoch 68/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.3001 - mae: 5.7232
# Epoch 69/100
# 31/31 [==============================] - 1s 29ms/step - loss: 5.3745 - mae: 5.8346
# Epoch 70/100
# 31/31 [==============================] - 1s 27ms/step - loss: 6.1347 - mae: 6.6380
# Epoch 71/100
# 31/31 [==============================] - 1s 26ms/step - loss: 4.9125 - mae: 5.4139
# Epoch 72/100
# 31/31 [==============================] - 1s 27ms/step - loss: 5.6092 - mae: 6.0629
# Epoch 73/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.3409 - mae: 5.8207
# Epoch 74/100
# 31/31 [==============================] - 1s 27ms/step - loss: 6.6826 - mae: 7.1954
# Epoch 75/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.6197 - mae: 6.0815
# Epoch 76/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.3481 - mae: 5.7991
# Epoch 77/100
# 31/31 [==============================] - 1s 25ms/step - loss: 5.1186 - mae: 5.6274
# Epoch 78/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.9973 - mae: 6.4255
# Epoch 79/100
# 31/31 [==============================] - 1s 26ms/step - loss: 6.0630 - mae: 6.5978
# Epoch 80/100
# 31/31 [==============================] - 1s 26ms/step - loss: 5.3291 - mae: 5.8422
# Epoch 81/100
# 31/31 [==============================] - 1s 25ms/step - loss: 5.1221 - mae: 5.5654: 1s - loss: 4.9623 - ma
# Epoch 82/100
# 31/31 [==============================] - 1s 26ms/step - loss: 6.7227 - mae: 7.2437
# Epoch 83/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.8594 - mae: 6.3610
# Epoch 84/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.6973 - mae: 7.1680
# Epoch 85/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.6486 - mae: 8.1846
# Epoch 86/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.0388 - mae: 7.4453
# Epoch 87/100
# 31/31 [==============================] - 1s 24ms/step - loss: 5.6651 - mae: 6.1308
# Epoch 88/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.8231 - mae: 7.4264
# Epoch 89/100
# 31/31 [==============================] - 1s 24ms/step - loss: 7.4148 - mae: 7.9712
# Epoch 90/100
# 31/31 [==============================] - 1s 25ms/step - loss: 9.0279 - mae: 9.4543
# Epoch 91/100
# 31/31 [==============================] - 1s 24ms/step - loss: 9.6677 - mae: 10.1714
# Epoch 92/100
# 31/31 [==============================] - 1s 25ms/step - loss: 10.1011 - mae: 10.5449
# Epoch 93/100
# 31/31 [==============================] - 1s 24ms/step - loss: 8.8712 - mae: 9.5810
# Epoch 94/100
# 31/31 [==============================] - 1s 24ms/step - loss: 11.0427 - mae: 11.5367
# Epoch 95/100
# 31/31 [==============================] - 1s 24ms/step - loss: 9.6372 - mae: 10.1993
# Epoch 96/100
# 31/31 [==============================] - 1s 25ms/step - loss: 8.5542 - mae: 9.0227
# Epoch 97/100
# 31/31 [==============================] - 1s 24ms/step - loss: 9.3591 - mae: 9.8286
# Epoch 98/100
# 31/31 [==============================] - 1s 24ms/step - loss: 8.6520 - mae: 9.0691
# Epoch 99/100
# 31/31 [==============================] - 1s 25ms/step - loss: 15.0576 - mae: 15.4362
# Epoch 100/100
# 31/31 [==============================] - 1s 24ms/step - loss: 13.7895 - mae: 14.2111

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 30])
# Out:
# [1e-08, 0.0001, 0, 30]

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

tf.keras.backend.clear_session()
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
   tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])


model.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(lr=1e-5, momentum=0.9),metrics=["mae"])
print(model.summary())
history = model.fit(dataset,epochs=500,verbose=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, None, 1)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 64)          8704
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                24832
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 1)                 0
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
forecast = []
results = []
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 6.1330013

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
mae=history.history['mae']
loss=history.history['loss']

epochs=range(len(loss)) # Get number of epochs

#------------------------------------------------
# Plot MAE and Loss
#------------------------------------------------
plt.plot(epochs, mae, 'r')
plt.plot(epochs, loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()

epochs_zoom = epochs[200:]
mae_zoom = mae[200:]
loss_zoom = loss[200:]

#------------------------------------------------
# Plot Zoomed MAE and Loss
#------------------------------------------------
plt.plot(epochs_zoom, mae_zoom, 'r')
plt.plot(epochs_zoom, loss_zoom, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()

# %%
tf.keras.backend.clear_session()
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])


model.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(lr=1e-6, momentum=0.9))
model.fit(dataset,epochs=100, verbose=0)

# %%
forecast = []
results = []
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 8.389499

# %%
tf.keras.backend.clear_session()
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])


model.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(lr=1e-6, momentum=0.9))
model.fit(dataset,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 9s 277ms/step - loss: 637.0232
# Epoch 2/100
# 31/31 [==============================] - 1s 34ms/step - loss: 122.3824
# Epoch 3/100
# 31/31 [==============================] - 1s 35ms/step - loss: 93.5221
# Epoch 4/100
# 31/31 [==============================] - 1s 34ms/step - loss: 89.9539
# Epoch 5/100
# 31/31 [==============================] - 1s 35ms/step - loss: 83.9737
# Epoch 6/100
# 31/31 [==============================] - 1s 34ms/step - loss: 75.3470
# Epoch 7/100
# 31/31 [==============================] - 1s 34ms/step - loss: 68.6464
# Epoch 8/100
# 31/31 [==============================] - 1s 34ms/step - loss: 64.6512
# Epoch 9/100
# 31/31 [==============================] - 1s 34ms/step - loss: 66.7151
# Epoch 10/100
# 31/31 [==============================] - 1s 34ms/step - loss: 65.4137
# Epoch 11/100
# 31/31 [==============================] - 1s 35ms/step - loss: 63.6606
# Epoch 12/100
# 31/31 [==============================] - 1s 36ms/step - loss: 58.3602
# Epoch 13/100
# 31/31 [==============================] - 1s 36ms/step - loss: 56.1278
# Epoch 14/100
# 31/31 [==============================] - 1s 36ms/step - loss: 63.2087
# Epoch 15/100
# 31/31 [==============================] - 1s 36ms/step - loss: 55.1125
# Epoch 16/100
# 31/31 [==============================] - 1s 35ms/step - loss: 52.6656
# Epoch 17/100
# 31/31 [==============================] - 1s 35ms/step - loss: 62.0863
# Epoch 18/100
# 31/31 [==============================] - 1s 34ms/step - loss: 59.2665
# Epoch 19/100
# 31/31 [==============================] - 1s 34ms/step - loss: 57.2411
# Epoch 20/100
# 31/31 [==============================] - 1s 33ms/step - loss: 58.1591
# Epoch 21/100
# 31/31 [==============================] - 1s 33ms/step - loss: 52.9893
# Epoch 22/100
# 31/31 [==============================] - 1s 34ms/step - loss: 48.8518
# Epoch 23/100
# 31/31 [==============================] - 1s 34ms/step - loss: 55.9563
# Epoch 24/100
# 31/31 [==============================] - 1s 36ms/step - loss: 49.5692
# Epoch 25/100
# 31/31 [==============================] - 1s 35ms/step - loss: 58.1519
# Epoch 26/100
# 31/31 [==============================] - 1s 36ms/step - loss: 49.3786
# Epoch 27/100
# 31/31 [==============================] - 1s 35ms/step - loss: 54.8172
# Epoch 28/100
# 31/31 [==============================] - 1s 36ms/step - loss: 53.7926
# Epoch 29/100
# 31/31 [==============================] - 1s 36ms/step - loss: 54.7583
# Epoch 30/100
# 31/31 [==============================] - 1s 36ms/step - loss: 48.5040
# Epoch 31/100
# 31/31 [==============================] - 1s 34ms/step - loss: 49.9654
# Epoch 32/100
# 31/31 [==============================] - 1s 35ms/step - loss: 52.8548
# Epoch 33/100
# 31/31 [==============================] - 1s 34ms/step - loss: 57.4627
# Epoch 34/100
# 31/31 [==============================] - 1s 34ms/step - loss: 48.4985
# Epoch 35/100
# 31/31 [==============================] - 1s 35ms/step - loss: 49.9536
# Epoch 36/100
# 31/31 [==============================] - 1s 39ms/step - loss: 48.0678
# Epoch 37/100
# 31/31 [==============================] - 1s 35ms/step - loss: 47.0031
# Epoch 38/100
# 31/31 [==============================] - 1s 34ms/step - loss: 51.8044
# Epoch 39/100
# 31/31 [==============================] - 1s 34ms/step - loss: 47.8402
# Epoch 40/100
# 31/31 [==============================] - 1s 37ms/step - loss: 47.0738
# Epoch 41/100
# 31/31 [==============================] - 1s 34ms/step - loss: 49.3223
# Epoch 42/100
# 31/31 [==============================] - 1s 36ms/step - loss: 46.2311
# Epoch 43/100
# 31/31 [==============================] - 1s 35ms/step - loss: 50.1677
# Epoch 44/100
# 31/31 [==============================] - 1s 35ms/step - loss: 49.0299
# Epoch 45/100
# 31/31 [==============================] - 1s 35ms/step - loss: 51.4375
# Epoch 46/100
# 31/31 [==============================] - 1s 35ms/step - loss: 48.7903 0s - loss: 49.
# Epoch 47/100
# 31/31 [==============================] - 1s 35ms/step - loss: 51.9893
# Epoch 48/100
# 31/31 [==============================] - 1s 35ms/step - loss: 50.1349
# Epoch 49/100
# 31/31 [==============================] - 1s 36ms/step - loss: 45.4001
# Epoch 50/100
# 31/31 [==============================] - 1s 36ms/step - loss: 45.3459
# Epoch 51/100
# 31/31 [==============================] - 1s 35ms/step - loss: 45.9184
# Epoch 52/100
# 31/31 [==============================] - 1s 35ms/step - loss: 48.6871
# Epoch 53/100
# 31/31 [==============================] - 1s 34ms/step - loss: 50.2157
# Epoch 54/100
# 31/31 [==============================] - 1s 37ms/step - loss: 50.3792
# Epoch 55/100
# 31/31 [==============================] - 1s 35ms/step - loss: 44.5867
# Epoch 56/100
# 31/31 [==============================] - 1s 35ms/step - loss: 46.2903
# Epoch 57/100
# 31/31 [==============================] - 1s 35ms/step - loss: 46.9808 0s - loss: 42.
# Epoch 58/100
# 31/31 [==============================] - 1s 36ms/step - loss: 46.0497
# Epoch 59/100
# 31/31 [==============================] - 1s 35ms/step - loss: 45.0362
# Epoch 60/100
# 31/31 [==============================] - 1s 35ms/step - loss: 45.3160
# Epoch 61/100
# 31/31 [==============================] - 1s 35ms/step - loss: 46.7116
# Epoch 62/100
# 31/31 [==============================] - 1s 35ms/step - loss: 46.7306
# Epoch 63/100
# 31/31 [==============================] - 1s 35ms/step - loss: 47.1439
# Epoch 64/100
# 31/31 [==============================] - 1s 35ms/step - loss: 45.2324
# Epoch 65/100
# 31/31 [==============================] - 1s 35ms/step - loss: 45.5615
# Epoch 66/100
# 31/31 [==============================] - 1s 35ms/step - loss: 44.5538
# Epoch 67/100
# 31/31 [==============================] - 1s 39ms/step - loss: 43.8195
# Epoch 68/100
# 31/31 [==============================] - 1s 37ms/step - loss: 44.7913
# Epoch 69/100
# 31/31 [==============================] - 1s 34ms/step - loss: 49.0834
# Epoch 70/100
# 31/31 [==============================] - 1s 36ms/step - loss: 49.2482
# Epoch 71/100
# 31/31 [==============================] - 1s 36ms/step - loss: 48.2154
# Epoch 72/100
# 31/31 [==============================] - 1s 36ms/step - loss: 43.9151
# Epoch 73/100
# 31/31 [==============================] - 1s 33ms/step - loss: 44.9549
# Epoch 74/100
# 31/31 [==============================] - 1s 34ms/step - loss: 44.6029
# Epoch 75/100
# 31/31 [==============================] - 1s 36ms/step - loss: 44.2298
# Epoch 76/100
# 31/31 [==============================] - 1s 36ms/step - loss: 43.6080
# Epoch 77/100
# 31/31 [==============================] - 1s 35ms/step - loss: 45.3792
# Epoch 78/100
# 31/31 [==============================] - 1s 36ms/step - loss: 45.6226
# Epoch 79/100
# 31/31 [==============================] - 1s 36ms/step - loss: 44.8075
# Epoch 80/100
# 31/31 [==============================] - 1s 35ms/step - loss: 44.7194
# Epoch 81/100
# 31/31 [==============================] - 1s 35ms/step - loss: 51.3381
# Epoch 82/100
# 31/31 [==============================] - 1s 36ms/step - loss: 52.6025
# Epoch 83/100
# 31/31 [==============================] - 1s 36ms/step - loss: 45.2575
# Epoch 84/100
# 31/31 [==============================] - 1s 36ms/step - loss: 45.2554
# Epoch 85/100
# 31/31 [==============================] - 1s 36ms/step - loss: 46.0116
# Epoch 86/100
# 31/31 [==============================] - 1s 36ms/step - loss: 45.1577
# Epoch 87/100
# 31/31 [==============================] - 1s 35ms/step - loss: 43.5127
# Epoch 88/100
# 31/31 [==============================] - 1s 36ms/step - loss: 51.4440
# Epoch 89/100
# 31/31 [==============================] - 1s 35ms/step - loss: 46.2988
# Epoch 90/100
# 31/31 [==============================] - 1s 35ms/step - loss: 49.2589
# Epoch 91/100
# 31/31 [==============================] - 1s 34ms/step - loss: 45.1823
# Epoch 92/100
# 31/31 [==============================] - 1s 35ms/step - loss: 52.0298
# Epoch 93/100
# 31/31 [==============================] - 1s 34ms/step - loss: 44.1537
# Epoch 94/100
# 31/31 [==============================] - 1s 35ms/step - loss: 41.8718 0s
# Epoch 95/100
# 31/31 [==============================] - 1s 35ms/step - loss: 46.0074
# Epoch 96/100
# 31/31 [==============================] - 1s 36ms/step - loss: 44.7369
# Epoch 97/100
# 31/31 [==============================] - 1s 37ms/step - loss: 44.7657
# Epoch 98/100
# 31/31 [==============================] - 1s 36ms/step - loss: 44.1665
# Epoch 99/100
# 31/31 [==============================] - 1s 35ms/step - loss: 44.7782
# Epoch 100/100
# 31/31 [==============================] - 1s 36ms/step - loss: 45.3298

# %%
forecast = []
results = []
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 5.4628363

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
mae=history.history['mae']
loss=history.history['loss']

epochs=range(len(loss)) # Get number of epochs

#------------------------------------------------
# Plot MAE and Loss
#------------------------------------------------
plt.plot(epochs, mae, 'r')
plt.plot(epochs, loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()

epochs_zoom = epochs[200:]
mae_zoom = mae[200:]
loss_zoom = loss[200:]

#------------------------------------------------
# Plot Zoomed MAE and Loss
#------------------------------------------------
plt.plot(epochs_zoom, mae_zoom, 'r')
plt.plot(epochs_zoom, loss_zoom, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()
